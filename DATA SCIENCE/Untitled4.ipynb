# %%
pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab.patches import cv2_imshow
import cv2
var = cv2.imread("dog..jpg")
var
# Out:
# array([[[104, 166, 148],
#         [105, 167, 149],
#         [105, 167, 149],
#         ...,
#         [108, 180, 168],
#         [108, 180, 168],
#         [110, 179, 168]],
#
#        [[104, 166, 148],
#         [105, 167, 149],
#         [105, 167, 149],
#         ...,
#         [110, 179, 168],
#         [110, 179, 168],
#         [110, 179, 168]],
#
#        [[105, 167, 149],
#         [105, 167, 149],
#         [106, 168, 150],
#         ...,
#         [111, 180, 167],
#         [111, 180, 167],
#         [111, 180, 167]],
#
#        ...,
#
#        [[ 81, 141, 123],
#         [ 90, 150, 132],
#         [ 76, 136, 118],
#         ...,
#         [ 93, 155, 137],
#         [ 82, 146, 127],
#         [ 80, 143, 127]],
#
#        [[ 68, 129, 109],
#         [ 82, 143, 123],
#         [ 73, 133, 115],
#         ...,
#         [ 94, 158, 139],
#         [ 73, 137, 118],
#         [ 71, 136, 120]],
#
#        [[ 57, 121,  99],
#         [ 64, 128, 106],
#         [ 61, 124, 104],
# ...

# %%
gray = cv2.cvtColor(var,cv2.COLOR_BAYER_RGGB2BGR_VNG)
gray.shape
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-26-dc0f9233a67c> in <module>
# ----> 1 gray = cv2.cvtColor(var,cv2.COLOR_BAYER_RGGB2BGR_VNG)
#       2 gray.shape
#
# error: OpenCV(4.6.0) /io/opencv/modules/imgproc/src/demosaicing.cpp:1721: error: (-215:Assertion failed) scn == 1 && (dcn == 3 || dcn == 4) in function 'demosaicing'

# %%
cv2_imshow(var)
# Out:
# <PIL.Image.Image image mode=RGB size=317x159 at 0x7FB38D297950>

# %%
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=317x159 at 0x7FB38C991B10>

# %%
gray = cv2.cvtColor(var,cv2.COLOR_BGR2BGR555)
gray.shape
# Out:
# (159, 317, 2)

# %%
cha = cv2.resize(var,(250,400))
cv2_imshow(cha)
# Out:
# <PIL.Image.Image image mode=RGB size=250x400 at 0x7FB38D1EB790>

# %%
gray1 = cv2.cvtColor(var,cv2.COLOR_RGB2HLS)
gray1.shape
# Out:
# (159, 317, 3)
