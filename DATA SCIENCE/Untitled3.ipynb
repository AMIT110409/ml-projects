# %%
def solve(*args):
  t=()
  l=[]
  for i in args:
    l.append(i)
  t=tuple(l)
  
  print(t)
solve(12)
solve("hello","pi","bye")
solve("x",12,0,0)
# Out:
# (12,)
# ('hello', 'pi', 'bye')
# ('x', 12, 0, 0)

# %%
def sample(a, b): 
    temp = a; 
    a = b; 
    b = temp; 
x = 2
y = 3
sample(x, y) 
print(x) 
print(y)
# Out:
# 2
# 3

# %%
def exam(s):
    print("in function",s)
    s=25
    print("in function after change",s)
s=147
print("before call:",s)
exam(s)
print("after call",s)
.
# Out:
# before call: 147
# in function 147
# in function after change 25
# after call 147

# %%
def demo(m):
  print(m)
demo(True)
# Out:
# True

# %%
i=5
for x in range(i ,i%5==0):
  print(x)

# %%
While True:
	Print (“HI!”)
# Out:
#   File "<ipython-input-4-0d3b09a0bf8f>", line 1
#     While True:
#              ^
# SyntaxError: invalid syntax
