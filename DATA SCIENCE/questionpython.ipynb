# %%
# Q1.write an iterative function to compute the factorial of a natural number

def factorial(n):
  fact=1
  for i in range (1,n):
    fact=fact*i
    return fact
   
    print(factorial(5))

# %%
def factorial__recursive(n):
# Out:
#   File "<ipython-input-8-41871270edb8>", line 1
#     def factorial__recursive(n):
#                                 ^
# SyntaxError: unexpected EOF while parsing

# %%
 def compute__ratio(x,n):
  ratio =x**n/ factorial(n)
  return ratio
  comute__ratio(2,3)

# %%
def compute__sum(x,N):
  sum = 1
  for i in range(N):

# %%
 def compute_sum_epsilon(x, epsilon):     
     sum = 1
     var = epsilon
     i =1 
     while var >= epsilon:
        var = compute_ratio(x,i)
        sum += var 
        i+= 1 
     return sum
print(compute_sum_epsilon(2,0.01))

# %%
p = -1.5
q = 7.1

v1 = compute_sum(p,100)* compute_sum(q,100)
v2 = compute_sum (p + q, 100)

print(v1 , v2 , v2 - v1)

for i in range(10):
     print(i , compute_sum(i , 100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-3923337125cb> in <module>()
#       2 q = 7.1
#       3
# ----> 4 v1 = compute_sum(p,100)* compute_sum(q,100)
#       5 v2 = compute_sum (p + q, 100)
#       6
#
# NameError: name 'compute_sum' is not defined
